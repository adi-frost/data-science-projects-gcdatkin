# %% [markdown]
# ## 💸 Company Market Value Prediction
#
# Given *data about the world's largest companies*, let's try to predict the **market value** of a given company.
#
# We will use a tensorflow/keras neural network to make our predictions.
#
# Data source: https://www.kaggle.com/datasets/jasmeet0516/largest-companies-in-world

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd

import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'iframe'

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
# Out:
# 2025-03-09 11:11:17.946053: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data = pd.read_csv("Largest companies in world.csv")
data
# Out:
#        rank                          organizationName        country  \
# 0         1                            JPMorgan Chase  United States
# 1         2  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia
# 2         3                                      ICBC          China
# 3         4                   China Construction Bank          China
# 4         5                Agricultural Bank of China          China
# ...     ...                                       ...            ...
# 2046  1,996                                Alfa Laval         Sweden
# 2047  1,996                                       Gap  United States
# 2048  1,996                                  Yes Bank          India
# 2049  1,999                                 BEKB-BCBE    Switzerland
# 2050  1,999                                     Ipsen         France
#
#        revenue   profits      assets marketValue
# 0     179.93 B    41.8 B   3,744.3 B    399.59 B
# 1     589.47 B  156.36 B    660.99 B  2,055.22 B
# 2     216.77 B   52.47 B  6,116.82 B    203.01 B
# 3     203.08 B   48.25 B  4,977.48 B    172.99 B
# 4     186.14 B   37.92 B  5,356.86 B    141.82 B
# ...        ...       ...         ...         ...
# 2046    5.35 B   489.5 M      7.82 B      15.6 B
# 2047   15.62 B    -202 M     11.39 B      3.17 B
# 2048    3.34 B    91.6 M     43.22 B       5.6 B
# 2049     556 M   167.1 M     42.97 B      2.49 B
# 2050    3.18 B   681.7 M      5.99 B     10.21 B
#
# [2051 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rank              2050 non-null   object
#  1   organizationName  2050 non-null   object
#  2   country           2050 non-null   object
#  3   revenue           2049 non-null   object
#  4   profits           2049 non-null   object
#  5   assets            2049 non-null   object
#  6   marketValue       2049 non-null   object
# dtypes: object(7)
# memory usage: 112.3+ KB

# %% [markdown]
# ### Preprocessing

# %%
df = data.copy()

# %%
df.isna().sum()
# Out:
# rank                1
# organizationName    1
# country             1
# revenue             2
# profits             2
# assets              2
# marketValue         2
# dtype: int64

# %%
# missing values in the dataframe
missing_value_rows = df.loc[df.isna().any(axis=1) == True, :]
missing_value_rows
# Out:
#     rank          organizationName        country revenue profits assets  \
# 39   NaN                       NaN            NaN     NaN     NaN    NaN
# 521  471  GE HealthCare Consulting  United States     NaN     NaN    NaN
#
#     marketValue
# 39          NaN
# 521         NaN

# %%
df = df.drop(missing_value_rows.index, axis=0)

# %%
df.isna().sum()
# Out:
# rank                0
# organizationName    0
# country             0
# revenue             0
# profits             0
# assets              0
# marketValue         0
# dtype: int64

# %%
df
# Out:
#        rank                          organizationName        country  \
# 0         1                            JPMorgan Chase  United States
# 1         2  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia
# 2         3                                      ICBC          China
# 3         4                   China Construction Bank          China
# 4         5                Agricultural Bank of China          China
# ...     ...                                       ...            ...
# 2046  1,996                                Alfa Laval         Sweden
# 2047  1,996                                       Gap  United States
# 2048  1,996                                  Yes Bank          India
# 2049  1,999                                 BEKB-BCBE    Switzerland
# 2050  1,999                                     Ipsen         France
#
#        revenue   profits      assets marketValue
# 0     179.93 B    41.8 B   3,744.3 B    399.59 B
# 1     589.47 B  156.36 B    660.99 B  2,055.22 B
# 2     216.77 B   52.47 B  6,116.82 B    203.01 B
# 3     203.08 B   48.25 B  4,977.48 B    172.99 B
# 4     186.14 B   37.92 B  5,356.86 B    141.82 B
# ...        ...       ...         ...         ...
# 2046    5.35 B   489.5 M      7.82 B      15.6 B
# 2047   15.62 B    -202 M     11.39 B      3.17 B
# 2048    3.34 B    91.6 M     43.22 B       5.6 B
# 2049     556 M   167.1 M     42.97 B      2.49 B
# 2050    3.18 B   681.7 M      5.99 B     10.21 B
#
# [2049 rows x 7 columns]

# %%
# Modifying numerical columns and Converting to correct data types
df['rank'] = df['rank'].str.replace(',', '').astype(int)
for col in ['revenue', 'profits', 'assets', 'marketValue']:
    df[col] = df[col].apply(lambda x: x.replace('B', '').replace('M', '').replace(',', '').strip()).astype('float')
df
# Out:
#       rank                          organizationName        country  revenue  \
# 0        1                            JPMorgan Chase  United States   179.93
# 1        2  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia   589.47
# 2        3                                      ICBC          China   216.77
# 3        4                   China Construction Bank          China   203.08
# 4        5                Agricultural Bank of China          China   186.14
# ...    ...                                       ...            ...      ...
# 2046  1996                                Alfa Laval         Sweden     5.35
# 2047  1996                                       Gap  United States    15.62
# 2048  1996                                  Yes Bank          India     3.34
# 2049  1999                                 BEKB-BCBE    Switzerland   556.00
# 2050  1999                                     Ipsen         France     3.18
#
#       profits   assets  marketValue
# 0       41.80  3744.30       399.59
# 1      156.36   660.99      2055.22
# 2       52.47  6116.82       203.01
# 3       48.25  4977.48       172.99
# 4       37.92  5356.86       141.82
# ...       ...      ...          ...
# 2046   489.50     7.82        15.60
# 2047  -202.00    11.39         3.17
# 2048    91.60    43.22         5.60
# 2049   167.10    42.97         2.49
# 2050   681.70     5.99        10.21
#
# [2049 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2049 entries, 0 to 2050
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rank              2049 non-null   int64
#  1   organizationName  2049 non-null   object
#  2   country           2049 non-null   object
#  3   revenue           2049 non-null   float64
#  4   profits           2049 non-null   float64
#  5   assets            2049 non-null   float64
#  6   marketValue       2049 non-null   float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 128.1+ KB

# %%
# Dropping unused columns
df = df.drop(['rank', 'organizationName'], axis=1)
df
# Out:
#             country  revenue  profits   assets  marketValue
# 0     United States   179.93    41.80  3744.30       399.59
# 1      Saudi Arabia   589.47   156.36   660.99      2055.22
# 2             China   216.77    52.47  6116.82       203.01
# 3             China   203.08    48.25  4977.48       172.99
# 4             China   186.14    37.92  5356.86       141.82
# ...             ...      ...      ...      ...          ...
# 2046         Sweden     5.35   489.50     7.82        15.60
# 2047  United States    15.62  -202.00    11.39         3.17
# 2048          India     3.34    91.60    43.22         5.60
# 2049    Switzerland   556.00   167.10    42.97         2.49
# 2050         France     3.18   681.70     5.99        10.21
#
# [2049 rows x 5 columns]

# %%
# One-hot encode the nominal feature columns
dummies = pd.get_dummies(df['country'], prefix='country')
df = pd.concat([df, dummies], axis= 1)
df = df.drop(['country'], axis=1)
df
# Out:
#       revenue  profits   assets  marketValue  country_Argentina  \
# 0      179.93    41.80  3744.30       399.59              False
# 1      589.47   156.36   660.99      2055.22              False
# 2      216.77    52.47  6116.82       203.01              False
# 3      203.08    48.25  4977.48       172.99              False
# 4      186.14    37.92  5356.86       141.82              False
# ...       ...      ...      ...          ...                ...
# 2046     5.35   489.50     7.82        15.60              False
# 2047    15.62  -202.00    11.39         3.17              False
# 2048     3.34    91.60    43.22         5.60              False
# 2049   556.00   167.10    42.97         2.49              False
# 2050     3.18   681.70     5.99        10.21              False
#
#       country_Australia  country_Austria  country_Belgium  country_Bermuda  \
# 0                 False            False            False            False
# 1                 False            False            False            False
# 2                 False            False            False            False
# 3                 False            False            False            False
# 4                 False            False            False            False
# ...                 ...              ...              ...              ...
# 2046              False            False            False            False
# 2047              False            False            False            False
# 2048              False            False            False            False
# 2049              False            False            False            False
# 2050              False            False            False            False
#
#       country_Brazil  ...  country_Sweden  country_Switzerland  \
# 0              False  ...           False                False
# 1              False  ...           False                False
# 2              False  ...           False                False
# 3              False  ...           False                False
# 4              False  ...           False                False
# ...              ...  ...             ...                  ...
# 2046           False  ...            True                False
# 2047           False  ...           False                False
# 2048           False  ...           False                False
# 2049           False  ...           False                 True
# 2050           False  ...           False                False
#
#       country_Taiwan  country_Thailand  country_Turkey  \
# 0              False             False           False
# 1              False             False           False
# 2              False             False           False
# 3              False             False           False
# 4              False             False           False
# ...              ...               ...             ...
# 2046           False             False           False
# 2047           False             False           False
# 2048           False             False           False
# 2049           False             False           False
# 2050           False             False           False
#
#       country_United Arab Emirates  country_United Kingdom  \
# 0                            False                   False
# 1                            False                   False
# 2                            False                   False
# 3                            False                   False
# 4                            False                   False
# ...                            ...                     ...
# 2046                         False                   False
# 2047                         False                   False
# 2048                         False                   False
# 2049                         False                   False
# 2050                         False                   False
#
#       country_United States  country_Uruguay  country_Vietnam
# 0                      True            False            False
# 1                     False            False            False
# 2                     False            False            False
# 3                     False            False            False
# 4                     False            False            False
# ...                     ...              ...              ...
# 2046                  False            False            False
# 2047                   True            False            False
# 2048                  False            False            False
# 2049                  False            False            False
# 2050                  False            False            False
#
# [2049 rows x 62 columns]

# %%
# Split df into X and y
X = df.drop('marketValue', axis=1)
y = df['marketValue']

# %%
# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True, random_state=1)

# %%
X_train
# Out:
#       revenue  profits   assets  country_Argentina  country_Australia  \
# 1718     7.62   987.40    13.47              False              False
# 738     18.93     1.84    24.84              False              False
# 16     108.93    14.50  1886.40              False              False
# 1258     3.76   888.60    94.63              False              False
# 1579     2.27   377.20   186.99              False              False
# ...       ...      ...      ...                ...                ...
# 1793     2.09   482.70    35.36              False              False
# 1098     4.00     1.10    31.10              False              False
# 1934     2.10   611.70     3.52              False              False
# 236     35.94     5.23    59.88              False              False
# 1063     6.94     1.23     5.75              False              False
#
#       country_Austria  country_Belgium  country_Bermuda  country_Brazil  \
# 1718            False            False            False            True
# 738             False            False            False           False
# 16              False            False            False           False
# 1258            False            False            False           False
# 1579            False            False            False           False
# ...               ...              ...              ...             ...
# 1793            False            False            False           False
# 1098            False            False            False           False
# 1934            False            False            False           False
# 236             False            False            False           False
# 1063            False            False            False           False
#
#       country_Canada  ...  country_Sweden  country_Switzerland  \
# 1718           False  ...           False                False
# 738            False  ...           False                False
# 16             False  ...           False                False
# 1258           False  ...           False                False
# 1579           False  ...           False                False
# ...              ...  ...             ...                  ...
# 1793           False  ...           False                False
# 1098           False  ...           False                False
# 1934           False  ...           False                False
# 236            False  ...           False                False
# 1063           False  ...           False                False
#
#       country_Taiwan  country_Thailand  country_Turkey  \
# 1718           False             False           False
# 738            False             False           False
# 16             False             False           False
# 1258           False             False           False
# 1579           False             False           False
# ...              ...               ...             ...
# 1793           False             False           False
# 1098           False             False           False
# 1934           False             False           False
# 236            False             False           False
# 1063           False             False           False
#
#       country_United Arab Emirates  country_United Kingdom  \
# 1718                         False                   False
# 738                          False                   False
# 16                           False                   False
# 1258                         False                   False
# 1579                         False                   False
# ...                            ...                     ...
# 1793                         False                   False
# 1098                         False                   False
# 1934                         False                   False
# 236                          False                   False
# 1063                         False                   False
#
#       country_United States  country_Uruguay  country_Vietnam
# 1718                  False            False            False
# 738                   False            False            False
# 16                     True            False            False
# 1258                  False            False            False
# 1579                  False            False            False
# ...                     ...              ...              ...
# 1793                  False            False            False
# 1098                  False            False            False
# 1934                  False            False            False
# 236                    True            False            False
# 1063                   True            False            False
#
# [1434 rows x 61 columns]

# %%
y_train
# Out:
# 1718      7.22
# 738      12.49
# 16      142.36
# 1258      5.95
# 1579      4.39
#          ...
# 1793      8.45
# 1098     14.72
# 1934     12.77
# 236     132.08
# 1063     38.51
# Name: marketValue, Length: 1434, dtype: float64

# %%
# Scale X
scaler = StandardScaler()
scaler.fit(X_train)
X_train = pd.DataFrame(scaler.transform(X_train), index=X_train.index, columns=X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test), index=X_test.index, columns=X_test.columns)

# %%
X_train
# Out:
#        revenue   profits    assets  country_Argentina  country_Australia  \
# 1718 -0.322508  2.210694 -0.274852          -0.026417          -0.133203
# 738  -0.215185 -0.635591 -0.250334          -0.026417          -0.133203
# 16    0.638848 -0.599029  3.764038          -0.026417          -0.133203
# 1258 -0.359137  1.925360 -0.099835          -0.026417          -0.133203
# 1579 -0.373276  0.448444  0.099336          -0.026417          -0.133203
# ...        ...       ...       ...                ...                ...
# 1793 -0.374984  0.753126 -0.227648          -0.026417          -0.133203
# 1098 -0.356860 -0.637728 -0.236834          -0.026417          -0.133203
# 1934 -0.374889  1.125677 -0.296309          -0.026417          -0.133203
# 236  -0.053773 -0.625801 -0.174771          -0.026417          -0.133203
# 1063 -0.328961 -0.637353 -0.291500          -0.026417          -0.133203
#
#       country_Austria  country_Belgium  country_Bermuda  country_Brazil  \
# 1718        -0.059152        -0.052889        -0.059152        9.414085
# 738         -0.059152        -0.052889        -0.059152       -0.106224
# 16          -0.059152        -0.052889        -0.059152       -0.106224
# 1258        -0.059152        -0.052889        -0.059152       -0.106224
# 1579        -0.059152        -0.052889        -0.059152       -0.106224
# ...               ...              ...              ...             ...
# 1793        -0.059152        -0.052889        -0.059152       -0.106224
# 1098        -0.059152        -0.052889        -0.059152       -0.106224
# 1934        -0.059152        -0.052889        -0.059152       -0.106224
# 236         -0.059152        -0.052889        -0.059152       -0.106224
# 1063        -0.059152        -0.052889        -0.059152       -0.106224
#
#       country_Canada  ...  country_Sweden  country_Switzerland  \
# 1718       -0.167203  ...       -0.109532            -0.130466
# 738        -0.167203  ...       -0.109532            -0.130466
# 16         -0.167203  ...       -0.109532            -0.130466
# 1258       -0.167203  ...       -0.109532            -0.130466
# 1579       -0.167203  ...       -0.109532            -0.130466
# ...              ...  ...             ...                  ...
# 1793       -0.167203  ...       -0.109532            -0.130466
# 1098       -0.167203  ...       -0.109532            -0.130466
# 1934       -0.167203  ...       -0.109532            -0.130466
# 236        -0.167203  ...       -0.109532            -0.130466
# 1063       -0.167203  ...       -0.109532            -0.130466
#
#       country_Taiwan  country_Thailand  country_Turkey  \
# 1718       -0.155839         -0.095648       -0.074901
# 738        -0.155839         -0.095648       -0.074901
# 16         -0.155839         -0.095648       -0.074901
# 1258       -0.155839         -0.095648       -0.074901
# 1579       -0.155839         -0.095648       -0.074901
# ...              ...               ...             ...
# 1793       -0.155839         -0.095648       -0.074901
# 1098       -0.155839         -0.095648       -0.074901
# 1934       -0.155839         -0.095648       -0.074901
# 236        -0.155839         -0.095648       -0.074901
# 1063       -0.155839         -0.095648       -0.074901
#
#       country_United Arab Emirates  country_United Kingdom  \
# 1718                       -0.0838               -0.192032
# 738                        -0.0838               -0.192032
# 16                         -0.0838               -0.192032
# 1258                       -0.0838               -0.192032
# 1579                       -0.0838               -0.192032
# ...                            ...                     ...
# 1793                       -0.0838               -0.192032
# 1098                       -0.0838               -0.192032
# 1934                       -0.0838               -0.192032
# 236                        -0.0838               -0.192032
# 1063                       -0.0838               -0.192032
#
#       country_United States  country_Uruguay  country_Vietnam
# 1718              -0.652263        -0.026417        -0.052889
# 738               -0.652263        -0.026417        -0.052889
# 16                 1.533123        -0.026417        -0.052889
# 1258              -0.652263        -0.026417        -0.052889
# 1579              -0.652263        -0.026417        -0.052889
# ...                     ...              ...              ...
# 1793              -0.652263        -0.026417        -0.052889
# 1098              -0.652263        -0.026417        -0.052889
# 1934              -0.652263        -0.026417        -0.052889
# 236                1.533123        -0.026417        -0.052889
# 1063               1.533123        -0.026417        -0.052889
#
# [1434 rows x 61 columns]

# %% [markdown]
# ### Training

# %%
inputs = tf.keras.Input(shape=(61,))
x = tf.keras.layers.Dense(128, activation='relu')(inputs)
x = tf.keras.layers.Dense(128, activation='relu')(x)
outputs = tf.keras.layers.Dense(1, activation='linear')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss = 'mse'
)

history = model.fit(
    X_train, 
    y_train,
    validation_split=0.2,
    batch_size=32,
    epochs=100,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/100
# 2025-03-09 11:11:19.980546: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 36/36 [==============================] - 1s 9ms/step - loss: 34235.1875 - val_loss: 13433.0195
# Epoch 2/100
# 36/36 [==============================] - 0s 5ms/step - loss: 32862.5859 - val_loss: 12070.1006
# Epoch 3/100
# 36/36 [==============================] - 0s 3ms/step - loss: 30256.2656 - val_loss: 11063.9150
# Epoch 4/100
# 36/36 [==============================] - 0s 3ms/step - loss: 28758.4629 - val_loss: 10713.5225
# Epoch 5/100
# 36/36 [==============================] - 0s 3ms/step - loss: 27719.7363 - val_loss: 10444.5283
# Epoch 6/100
# 36/36 [==============================] - 0s 3ms/step - loss: 26987.8164 - val_loss: 10228.9395
# Epoch 7/100
# 36/36 [==============================] - 0s 4ms/step - loss: 26378.9238 - val_loss: 10012.1426
# Epoch 8/100
# 36/36 [==============================] - 0s 3ms/step - loss: 25859.1191 - val_loss: 9859.1553
# Epoch 9/100
# 36/36 [==============================] - 0s 3ms/step - loss: 25283.8770 - val_loss: 9865.6270
# Epoch 10/100
# 36/36 [==============================] - 0s 3ms/step - loss: 24913.5371 - val_loss: 9786.5430
# Epoch 11/100
# 36/36 [==============================] - 0s 3ms/step - loss: 24488.3242 - val_loss: 9797.2656
# Epoch 12/100
# 36/36 [==============================] - 0s 6ms/step - loss: 24159.8867 - val_loss: 9846.0303
# Epoch 13/100
# 36/36 [==============================] - 0s 5ms/step - loss: 23943.4531 - val_loss: 9874.0479

# %% [markdown]
# ### Results

# %%
y_pred = np.squeeze(model.predict(X_test))
y_pred
# Out:
# 20/20 [==============================] - 0s 2ms/step
# array([ 4.30540428e+01,  8.47149963e+01,  4.35037766e+01,  1.23080490e+02,
#         1.10861473e+02,  2.46952763e+01,  3.24130898e+01,  1.26840391e+01,
#         7.69616623e+01,  1.67255554e+01,  4.07580414e+01,  6.66974030e+01,
#         5.10361633e+01,  8.53139801e+01,  5.48616943e+01,  9.54988174e+01,
#         3.57635078e+01,  1.06282797e+01,  5.95956497e+01,  1.04352293e+01,
#         2.26722260e+02,  5.56272621e+01,  2.80481529e+01,  4.93739853e+01,
#         1.04293503e+02,  2.67971497e+01,  6.72802811e+01,  7.74808273e+01,
#         4.81857300e+01,  5.41150856e+01,  2.44541969e+01,  1.87779312e+01,
#         3.78569756e+01,  2.27705269e+01,  1.70983715e+01,  7.97764397e+00,
#         1.72247696e+02,  1.99783363e+01,  2.69243107e+01,  7.06138992e+01,
#         9.48235512e+00,  1.12860382e+02,  7.89486542e+01,  4.23209534e+01,
#         5.16139565e+01,  7.01233215e+01,  5.29865608e+01,  2.04170475e+01,
#         5.01685600e+01,  3.83889351e+01,  2.13459263e+01,  7.45340805e+01,
#         3.02484665e+01,  3.59345627e+01,  7.71311569e+01,  3.43133774e+01,
#         5.51128006e+01, -1.21898687e+00, -3.05367446e+00,  3.81768036e+01,
#         2.29940395e+01,  7.42868576e+01,  7.18017120e+01,  1.03325386e+02,
#         5.73750305e+01,  4.41852417e+01,  3.34664879e+01,  1.20728140e+01,
#         1.48765688e+01,  9.57913589e+01,  3.86600723e+01,  3.88290901e+01,
#         1.71011505e+01,  3.74670258e+01,  9.41671371e+00,  5.36435165e+01,
#         8.45003986e+00,  3.46906067e+02,  7.72835770e+01,  9.74175034e+01,
#         1.78507957e+01,  3.94828987e+01,  7.63468094e+01,  4.73919716e+01,
#         1.75997314e+01,  4.78151016e+01,  3.85475082e+01,  1.39189825e+01,
#         2.19535065e+01,  7.09330978e+01,  5.05126686e+01,  9.44608536e+01,
#         2.38890266e+01,  4.39176941e+01,  2.53666611e+02,  1.86762894e+02,
#         5.08594513e+01,  8.86968155e+01,  2.78788300e+01,  5.56444778e+01,
#         2.77200470e+01,  4.25710526e+01,  9.38689804e+01,  7.35884933e+01,
#         6.95596237e+01,  2.74804745e+01,  6.95212631e+01,  8.97004032e+00,
#         1.78922749e+01,  1.49035273e+01,  1.60117172e+02,  3.06173286e+01,
#         3.63360367e+01,  4.92677841e+01,  1.55594120e+01,  1.97772655e+01,
#         2.64939606e+02,  2.28185329e+01,  3.95655990e+00,  1.02653557e+02,
#         8.33050919e+01,  7.61883163e+01,  4.41358185e+01,  7.52861099e+01,
#         4.13704910e+01,  3.84999207e+02,  1.04458450e+02,  5.56441284e+02,
#         6.59561462e+01,  3.74347916e+01,  1.42320602e+02,  2.94766769e+01,
#         3.48705902e+01,  2.97150631e+01,  4.76005402e+01,  2.22403564e+01,
#         2.46216858e+02,  7.67624741e+01,  3.70045135e+02,  7.13040085e+01,
#         7.71012039e+01,  4.33092842e+01,  4.28607368e+00,  4.21908989e+01,
#         5.81776314e+01,  4.13157005e+01,  1.31564636e+01,  4.79466629e+01,
#         1.18552809e+01,  1.08935909e+01,  4.74604530e+01,  7.67490101e+00,
#         4.11736725e+02,  1.56322145e+01,  7.82524872e+01,  1.08508530e+01,
#         1.06495228e+01,  5.78478909e+00,  1.07789841e+01,  9.35431519e+01,
#         3.97005386e+01,  4.45812073e+01,  1.43424597e+01,  2.50511131e+01,
#         6.23909426e+00,  2.35205650e+01,  8.69586716e+01], dtype=float32)

# %%
y_test
# Out:
# 404      38.60
# 352     122.91
# 677      25.43
# 103      51.58
# 182      47.07
#          ...
# 1002     38.32
# 1512      6.58
# 1827      5.03
# 1398      8.47
# 287      67.85
# Name: marketValue, Length: 615, dtype: float64

# %%
rmse = np.sqrt(np.mean((y_test - y_pred)**2))
rmse
# Out:
# 184.098185357547

# %%
y_test.describe()
# Out:
# count     615.000000
# mean       61.911951
# std       196.702525
# min         1.020000
# 25%         8.345000
# 50%        17.070000
# 75%        38.295000
# max      2309.840000
# Name: marketValue, dtype: float64

# %%
## R2 score calculation
np.sum((y_test - y_pred)**2)
# Out:
# 20843667.238944165

# %%
np.sum((y_test - y_test.mean())**2)
# Out:
# 23756816.26685854

# %%
r2_score = 1 - (np.sum((y_test - y_pred)**2) / np.sum((y_test - y_test.mean())**2))
r2_score
# Out:
# 0.12262371334572741

# %%
print("RMSE: {:.2f}".format(rmse))
print("R-Squared: {:.4f}".format(r2_score))

fig = px.scatter(
    x=y_pred,
    y=y_test,
    labels={'x': 'Predicted', 'y': 'Actual'},
    title='Actual vs Predicted Values',
    width = 700,
    height = 700
)
fig.show()
# Out:
# RMSE: 184.10
# R-Squared: 0.1226
# <iframe
#     scrolling="no"
#     width="720px"
#     height="720"
#     src="iframe_figures/figure_29.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

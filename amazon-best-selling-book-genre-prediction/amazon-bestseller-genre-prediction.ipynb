# %% [markdown]
# ## 📖 ⭐ Amazon BestSeller Genre Prediction
#
# Given *data about Amazon's top 50 best selling books from 2009-2019*, let's try to predict the **genre** of a given book.
#
# We will use a Tensorflow ANN with two inputs to make our predictions.
#
# Data source: https://www.kaggle.com/datasets/sootersaalu/amazon-top-50-bestselling-books-2009-2019

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd

import re
from nltk.corpus import stopwords
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf
# Out:
# 2025-03-02 09:33:45.969768: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data = pd.read_csv("bestsellers with categories.csv")
data
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %% [markdown]
# ### Preprocessing

# %%
stop_words = stopwords.words('english')
stop_words
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
def process_name(name):
    name = re.sub(r'\d+', ' ', name)
    name = name.split()
    name = " ".join([word for word in name if word not in stop_words])
    return name

# %%
names = data['Name'].apply(process_name)
names
# Out:
# 0                            -Day Green Smoothie Cleanse
# 1                                          / / : A Novel
# 2                          Rules Life: An Antidote Chaos
# 3                                      (Signet Classics)
# 4      , Awesome Facts (About Everything!) (National ...
#                              ...
# 545                Wrecking Ball (Diary Wimpy Kid Book )
# 546    You Are Badass: How Stop Doubting Your Greatne...
# 547    You Are Badass: How Stop Doubting Your Greatne...
# 548    You Are Badass: How Stop Doubting Your Greatne...
# 549    You Are Badass: How Stop Doubting Your Greatne...
# Name: Name, Length: 550, dtype: object

# %%
names.apply(lambda name: len(name.split()))
# Out:
# 0       4
# 1       5
# 2       5
# 3       2
# 4       8
#        ..
# 545     7
# 546    12
# 547    12
# 548    12
# 549    12
# Name: Name, Length: 550, dtype: int64

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(names)

tokenizer.word_index
# Out:
# {'the': 1,
#  'a': 2,
#  'book': 3,
#  'you': 4,
#  'love': 5,
#  'edition': 6,
#  'life': 7,
#  'guide': 8,
#  'novel': 9,
#  'your': 10,
#  'coloring': 11,
#  'that': 12,
#  'kids': 13,
#  'man': 14,
#  'how': 15,
#  'american': 16,
#  'series': 17,
#  'fifty': 18,
#  'shades': 19,
#  'dog': 20,
#  'world': 21,
#  'girl': 22,
#  'people': 23,
#  'cookbook': 24,
#  'art': 25,
#  'manual': 26,
#  'harry': 27,
#  'potter': 28,
#  'secret': 29,
#  'killing': 30,
#  'personal': 31,
#  'books': 32,
#  'kid': 33,
#  'th': 34,
#  'little': 35,
#  'good': 36,
#  'an': 37,
#  'from': 38,
#  'what': 39,
#  'recipes': 40,
#  'diary': 41,
#  'wimpy': 42,
#  'hunger': 43,
#  'games': 44,
#  'change': 45,
#  'story': 46,
#  'languages': 47,
#  'official': 48,
#  'day': 49,
#  'fire': 50,
#  'stop': 51,
#  'f': 52,
#  'trilogy': 53,
#  'one': 54,
#  'go': 55,
#  'to': 56,
#  'things': 57,
#  'publication': 58,
#  'psychological': 59,
#  'association': 60,
#  'lasts': 61,
#  'living': 62,
#  'great': 63,
#  'first': 64,
#  'food': 65,
#  'eat': 66,
#  'weight': 67,
#  'grey': 68,
#  'who': 69,
#  'are': 70,
#  'why': 71,
#  'new': 72,
#  'kitchen': 73,
#  'strengthsfinder': 74,
#  'study': 75,
#  'freedom': 76,
#  'game': 77,
#  'war': 78,
#  'time': 79,
#  'like': 80,
#  'twilight': 81,
#  'ck': 82,
#  "can't": 83,
#  'be': 84,
#  'set': 85,
#  'with': 86,
#  'his': 87,
#  'peace': 88,
#  'jokes': 89,
#  'oh': 90,
#  'places': 91,
#  "you'll": 92,
#  'habits': 93,
#  'thug': 94,
#  'dance': 95,
#  'thrones': 96,
#  'adult': 97,
#  'big': 98,
#  'easy': 99,
#  'creator': 100,
#  'captain': 101,
#  'underpants': 102,
#  'where': 103,
#  'out': 104,
#  'make': 105,
#  'goodnight': 106,
#  'heaven': 107,
#  'jesus': 108,
#  'wisdom': 109,
#  'practical': 110,
#  'highly': 111,
#  'effective': 112,
#  'powerful': 113,
#  'lessons': 114,
#  'sat': 115,
#  'very': 116,
#  'hungry': 117,
#  'caterpillar': 118,
#  'about': 119,
#  'leadership': 120,
#  'memoir': 121,
#  'can': 122,
#  'live': 123,
#  'lift': 124,
#  'flap': 125,
#  'path': 126,
#  'will': 127,
#  'not': 128,
#  'survival': 129,
#  'diet': 130,
#  'fast': 131,
#  'boxed': 132,
#  'back': 133,
#  'calling': 134,
#  'enjoying': 135,
#  'presence': 136,
#  'scripture': 137,
#  'references': 138,
#  'bill': 139,
#  "o'reilly's": 140,
#  'ii': 141,
#  'knock': 142,
#  'resilience': 143,
#  'up': 144,
#  'olympus': 145,
#  'lose': 146,
#  'five': 147,
#  'four': 148,
#  'agreements': 149,
#  'toltec': 150,
#  'millennium': 151,
#  'help': 152,
#  'awesome': 153,
#  'dragons': 154,
#  'truth': 155,
#  'animals': 156,
#  'we': 157,
#  'and': 158,
#  'is': 159,
#  'saga': 160,
#  'our': 161,
#  'bear': 162,
#  'do': 163,
#  'crazy': 164,
#  'creative': 165,
#  'sookie': 166,
#  'stackhouse': 167,
#  'true': 168,
#  'blood': 169,
#  'last': 170,
#  'illustrated': 171,
#  'words': 172,
#  'giraffes': 173,
#  'start': 174,
#  'leap': 175,
#  "don't": 176,
#  'moon': 177,
#  'wheat': 178,
#  'win': 179,
#  'friends': 180,
#  'influence': 181,
#  'when': 182,
#  'forever': 183,
#  'laugh': 184,
#  'loud': 185,
#  'success': 186,
#  'school': 187,
#  'power': 188,
#  'heroes': 189,
#  'dysfunctions': 190,
#  'team': 191,
#  'fable': 192,
#  'give': 193,
#  'health': 194,
#  'kill': 195,
#  'mockingbird': 196,
#  'unbroken': 197,
#  'redemption': 198,
#  'wonder': 199,
#  'national': 200,
#  'geographic': 201,
#  'clash': 202,
#  'kings': 203,
#  'storm': 204,
#  'swords': 205,
#  'feast': 206,
#  'crows': 207,
#  'designs': 208,
#  'stress': 209,
#  'see': 210,
#  'plan': 211,
#  'brown': 212,
#  'god': 213,
#  'rich': 214,
#  'haven': 215,
#  'gone': 216,
#  'family': 217,
#  'dear': 218,
#  'zoo': 219,
#  'for': 220,
#  'body': 221,
#  'healing': 222,
#  'wild': 223,
#  'this': 224,
#  'no': 225,
#  'loss': 226,
#  'three': 227,
#  'some': 228,
#  'companies': 229,
#  'others': 230,
#  'preschool': 231,
#  'i': 232,
#  'if': 233,
#  'night': 234,
#  'instant': 235,
#  'pot': 236,
#  'pressure': 237,
#  'cooker': 238,
#  'beginners': 239,
#  'p': 240,
#  'america': 241,
#  'milk': 242,
#  'handbook': 243,
#  'americans': 244,
#  'pre': 245,
#  'boat': 246,
#  'fault': 247,
#  'stars': 248,
#  'changing': 249,
#  'magic': 250,
#  'tidying': 251,
#  'japanese': 252,
#  'decluttering': 253,
#  'organizing': 254,
#  'pout': 255,
#  'total': 256,
#  'wonderful': 257,
#  'cookbooks': 258,
#  'badass': 259,
#  'doubting': 260,
#  'greatness': 261,
#  'everything': 262,
#  'lies': 263,
#  'garden': 264,
#  'all': 265,
#  'autobiography': 266,
#  'most': 267,
#  'barefoot': 268,
#  'contessa': 269,
#  'becoming': 270,
#  'me': 271,
#  'mind': 272,
#  'catching': 273,
#  'overwhelmed': 274,
#  'relentless': 275,
#  'stone': 276,
#  'way': 277,
#  'dead': 278,
#  'hard': 279,
#  'brain': 280,
#  'divergent': 281,
#  'more': 282,
#  'program': 283,
#  'eclipse': 284,
#  'quest': 285,
#  'find': 286,
#  'house': 287,
#  'revolution': 288,
#  'going': 289,
#  'gratitude': 290,
#  'happy': 291,
#  'my': 292,
#  'faith': 293,
#  'humans': 294,
#  'york': 295,
#  'berlin': 296,
#  'journey': 297,
#  'changed': 298,
#  'strange': 299,
#  'adventures': 300,
#  'lettering': 301,
#  'bed': 302,
#  'mastering': 303,
#  'cooking': 304,
#  'honey': 305,
#  'classic': 306,
#  'mindset': 307,
#  'psychology': 308,
#  'mockingjay': 309,
#  'mission': 310,
#  'dare': 311,
#  'train': 312,
#  'percy': 313,
#  'jackson': 314,
#  'olympians': 315,
#  "player's": 316,
#  'dungeons': 317,
#  'essential': 318,
#  'fat': 319,
#  'ages': 320,
#  'techniques': 321,
#  'should': 322,
#  'crayons': 323,
#  'quit': 324,
#  'gatsby': 325,
#  'immortal': 326,
#  'henrietta': 327,
#  'lacks': 328,
#  'healthy': 329,
#  'meals': 330,
#  'lost': 331,
#  'pioneer': 332,
#  'woman': 333,
#  'cooks': 334,
#  'kane': 335,
#  'chronicles': 336,
#  'subtle': 337,
#  'giving': 338,
#  'counterintuitive': 339,
#  'approach': 340,
#  'than': 341,
#  'whole': 342,
#  'rules': 343,
#  'classics': 344,
#  'facts': 345,
#  'ice': 346,
#  'called': 347,
#  'ove': 348,
#  'history': 349,
#  'united': 350,
#  'states': 351,
#  'terror': 352,
#  'think': 353,
#  'commitment': 354,
#  'mandalas': 355,
#  'patterns': 356,
#  'relieving': 357,
#  'animal': 358,
#  'adults': 359,
#  'inspired': 360,
#  'flowers': 361,
#  'hamilton': 362,
#  'light': 363,
#  'cannot': 364,
#  'sniper': 365,
#  'u': 366,
#  's': 367,
#  'government': 368,
#  'mark': 369,
#  'vol': 370,
#  'feel': 371,
#  'trust': 372,
#  'end': 373,
#  'between': 374,
#  'treasure': 375,
#  'down': 376,
#  'irreverent': 377,
#  'century': 378,
#  'want': 379,
#  'asians': 380,
#  'cutting': 381,
#  'lead': 382,
#  'diagnostic': 383,
#  'statistical': 384,
#  'mental': 385,
#  'disorders': 386,
#  'dsm': 387,
#  'difficult': 388,
#  'riddles': 389,
#  'smart': 390,
#  'divine': 391,
#  'soul': 392,
#  'heal': 393,
#  'earth': 394,
#  'sleep': 395,
#  'days': 396,
#  'volume': 397,
#  'tale': 398,
#  'two': 399,
#  'brawl': 400,
#  'ball': 401,
#  'surprising': 402,
#  'us': 403,
#  'solution': 404,
#  'simple': 405,
#  'amazing': 406,
#  'nutrient': 407,
#  'sustained': 408,
#  'revised': 409,
#  'educated': 410,
#  'inky': 411,
#  'mindfulness': 412,
#  'fahrenheit': 413,
#  'beasts': 414,
#  'trump': 415,
#  'white': 416,
#  'darker': 417,
#  'freed': 418,
#  'inside': 419,
#  'frozen': 420,
#  'golden': 421,
#  'obama': 422,
#  'race': 423,
#  'george': 424,
#  "washington's": 425,
#  'sacred': 426,
#  'free': 427,
#  'wash': 428,
#  'face': 429,
#  'believing': 430,
#  'so': 431,
#  'become': 432,
#  'were': 433,
#  'meant': 434,
#  'case': 435,
#  'of': 436,
#  'thomas': 437,
#  'week': 438,
#  'construction': 439,
#  'site': 440,
#  'hardcover': 441,
#  'toddlers': 442,
#  'sugar': 443,
#  'silent': 444,
#  'killers': 445,
#  'paperback': 446,
#  'real': 447,
#  "boy's": 448,
#  'astounding': 449,
#  'trip': 450,
#  'hillbilly': 451,
#  'elegy': 452,
#  'culture': 453,
#  'crisis': 454,
#  'leave': 455,
#  'other': 456,
#  'happened': 457,
#  'brave': 458,
#  'kissed': 459,
#  'in': 460,
#  'inheritance': 461,
#  'everyday': 462,
#  'advanced': 463,
#  'users': 464,
#  'try': 465,
#  'healthy…': 466,
#  'finding': 467,
#  'unexpected': 468,
#  'lincoln': 469,
#  'shocking': 470,
#  'assassination': 471,
#  'sun': 472,
#  'presents': 473,
#  'bundo': 474,
#  'women': 475,
#  'ever': 476,
#  'magnolia': 477,
#  'collection': 478,
#  'it': 479,
#  'over': 480,
#  'answers': 481,
#  'thousand': 482,
#  'gifts': 483,
#  'fully': 484,
#  'right': 485,
#  'outliers': 486,
#  'potty': 487,
#  'sesame': 488,
#  'street': 489,
#  'pokémon': 490,
#  'proof': 491,
#  "neurosurgeon's": 492,
#  'afterlife': 493,
#  'quiet': 494,
#  'introverts': 495,
#  'talking': 496,
#  'radical': 497,
#  'taking': 498,
#  'dream': 499,
#  'ready': 500,
#  'player': 501,
#  'rush': 502,
#  'revere': 503,
#  'travel': 504,
#  'exceptional': 505,
#  'salt': 506,
#  'acid': 507,
#  'heat': 508,
#  'elements': 509,
#  'zone': 510,
#  'workbook': 511,
#  'colors': 512,
#  'shapes': 513,
#  'numbers': 514,
#  'alphabet': 515,
#  'writing': 516,
#  'reading…': 517,
#  'class': 518,
#  'ancient': 519,
#  'steve': 520,
#  'jobs': 521,
#  'planet': 522,
#  'teach': 523,
#  'champion': 524,
#  'put': 525,
#  'students': 526,
#  'college': 527,
#  'rapid': 528,
#  'year': 529,
#  'racing': 530,
#  'rain': 531,
#  'short': 532,
#  'disease': 533,
#  'thief': 534,
#  'pictures': 535,
#  'boys': 536,
#  'nine': 537,
#  'their': 538,
#  'epic': 539,
#  'gold': 540,
#  'olympics': 541,
#  'complete': 542,
#  'ketogenic': 543,
#  'keto': 544,
#  'lifestyle': 545,
#  'steps': 546,
#  'kicked': 547,
#  "hornet's": 548,
#  'nest': 549,
#  'played': 550,
#  'dragon': 551,
#  'tattoo': 552,
#  'goldfinch': 553,
#  'pulitzer': 554,
#  'prize': 555,
#  'fiction': 556,
#  'electric': 557,
#  'olympian': 558,
#  'lego': 559,
#  'ideas': 560,
#  'unlock': 561,
#  'imagination': 562,
#  'nightingale': 563,
#  'wife': 564,
#  'step': 565,
#  'delicious': 566,
#  'plant': 567,
#  'paradox': 568,
#  'fish': 569,
#  'shack': 570,
#  'tragedy': 571,
#  'confronts': 572,
#  'eternity': 573,
#  'wheel': 574,
#  'wonky': 575,
#  'donkey': 576,
#  'thinking': 577,
#  'slow': 578,
#  'thirteen': 579,
#  'cups': 580,
#  'tea': 581,
#  "man's": 582,
#  'promote': 583,
#  'belly': 584,
#  'green': 585,
#  'smoothie': 586,
#  'cleanse': 587,
#  'antidote': 588,
#  'chaos': 589,
#  'signet': 590,
#  'song': 591,
#  'gentleman': 592,
#  'moscow': 593,
#  'higher': 594,
#  'loyalty': 595,
#  "patriot's": 596,
#  "columbus's": 597,
#  'discovery': 598,
#  'stolen': 599,
#  'wrinkle': 600,
#  'quintet': 601,
#  'act': 602,
#  'lady': 603,
#  'men': 604,
#  'really': 605,
#  'relationships': 606,
#  'intimacy': 607,
#  'relief': 608,
#  'paisley': 609,
#  'featuring': 610,
#  'henna': 611,
#  'paisley…': 612,
#  'alexander': 613,
#  'allegiant': 614,
#  'lethal': 615,
#  'military': 616,
#  'mountains': 617,
#  'echoed': 618,
#  'arguing': 619,
#  'idiots': 620,
#  'small': 621,
#  'minds': 622,
#  'astrophysics': 623,
#  'hurry': 624,
#  'twain': 625,
#  'baby': 626,
#  'touch': 627,
#  'balance': 628,
#  "angie's": 629,
#  'extreme': 630,
#  'menders': 631,
#  'foolproof': 632,
#  'fabulous': 633,
#  'tips': 634,
#  'being': 635,
#  'mortal': 636,
#  'medicine': 637,
#  'matters': 638,
#  'born': 639,
#  'run': 640,
#  'breaking': 641,
#  'dawn': 642,
#  'broke': 643,
#  'restore': 644,
#  'cabin': 645,
#  'fever': 646,
#  'calm': 647,
#  'hurt': 648,
#  'master': 649,
#  'defy': 650,
#  'odds': 651,
#  'capital': 652,
#  'twenty': 653,
#  'cravings': 654,
#  'cats': 655,
#  'owls': 656,
#  'daring': 657,
#  'greatly': 658,
#  'courage': 659,
#  'vulnerable': 660,
#  'transforms': 661,
#  'parent': 662,
#  'david': 663,
#  'goliath': 664,
#  'underdogs': 665,
#  'misfits': 666,
#  'battling': 667,
#  'giants': 668,
#  'reckoning': 669,
#  'decision': 670,
#  'points': 671,
#  'delivering': 672,
#  'happiness': 673,
#  'profits': 674,
#  'passion': 675,
#  'purpose': 676,
#  'luck': 677,
#  'straw': 678,
#  'long': 679,
#  'haul': 680,
#  'teasers': 681,
#  'families': 682,
#  'insurgent': 683,
#  'transmission': 684,
#  'system': 685,
#  'humanity': 686,
#  'mother': 687,
#  'all…': 688,
#  'doctor': 689,
#  'cat': 690,
#  'kitties': 691,
#  'fetch': 692,
#  'whom': 693,
#  'rolls': 694,
#  'lord': 695,
#  'fleas': 696,
#  'double': 697,
#  'dover': 698,
#  'nouveau': 699,
#  'drive': 700,
#  'motivates': 701,
#  'supermarket': 702,
#  'thousands': 703,
#  'swaps': 704,
#  'save': 705,
#  'pounds': 706,
#  'or': 707,
#  'sagas': 708,
#  'enchanted': 709,
#  'forest': 710,
#  'activity': 711,
#  'meditation': 712,
#  'floral': 713,
#  'prints…': 714,
#  'fantastic': 715,
#  'them': 716,
#  'original': 717,
#  'screenplay': 718,
#  'fear': 719,
#  'english': 720,
#  'fury': 721,
#  "eater's": 722,
#  'clintons': 723,
#  'mccain': 724,
#  'palin': 725,
#  'lifetime': 726,
#  'six': 727,
#  'spy': 728,
#  'ring': 729,
#  'saved': 730,
#  'apologizing': 731,
#  'shame': 732,
#  'embracing': 733,
#  'achieving': 734,
#  'goals': 735,
#  'glenn': 736,
#  "beck's": 737,
#  'common': 738,
#  'sense': 739,
#  'against': 740,
#  'control': 741,
#  'paine': 742,
#  'watchman': 743,
#  'k': 744,
#  'rogue': 745,
#  'cultivate': 746,
#  'attitude': 747,
#  'journal': 748,
#  'grain': 749,
#  'carbs': 750,
#  "brain's": 751,
#  'told': 752,
#  'christian': 753,
#  'guts': 754,
#  'legacy': 755,
#  'duck': 756,
#  'commander': 757,
#  'chamber': 758,
#  'secrets': 759,
#  'cursed': 760,
#  'child': 761,
#  'parts': 762,
#  'special': 763,
#  'rehearsal': 764,
#  'script': 765,
#  'goblet': 766,
#  'prisoner': 767,
#  'azkaban': 768,
#  "sorcerer's": 769,
#  'box': 770,
#  'have': 771,
#  'homebody': 772,
#  'creating': 773,
#  'spaces': 774,
#  'never': 775,
#  'howard': 776,
#  'stern': 777,
#  'comes': 778,
#  'again': 779,
#  'stories': 780,
#  'hyperbole': 781,
#  'half': 782,
#  'unfortunate': 783,
#  'situations': 784,
#  'flawed': 785,
#  'coping': 786,
#  'mechanisms': 787,
#  'mayhem': 788,
#  'am': 789,
#  'confident': 790,
#  'beautiful': 791,
#  'girls': 792,
#  'alex': 793,
#  'cross': 794,
#  'stay': 795,
#  "hitler's": 796,
#  'inferno': 797,
#  'iv': 798,
#  'cycle': 799,
#  "it's": 800,
#  'supposed': 801,
#  'strength': 802,
#  'disappointments': 803,
#  'shattered': 804,
#  'joyland': 805,
#  'crime': 806,
#  'flower': 807,
#  'osage': 808,
#  'murders': 809,
#  'birth': 810,
#  'fbi': 811,
#  'kennedy': 812,
#  'camelot': 813,
#  'patton': 814,
#  'death': 815,
#  "ii's": 816,
#  'audacious': 817,
#  'general': 818,
#  'reagan': 819,
#  'violent': 820,
#  'assault': 821,
#  'presidency': 822,
#  'rising': 823,
#  'vanquished': 824,
#  'japan': 825,
#  'confidential': 826,
#  'updated': 827,
#  'culinary': 828,
#  'underbelly': 829,
#  'tonight': 830,
#  'john': 831,
#  'oliver': 832,
#  'marlon': 833,
#  'better': 834,
#  'lgbt': 835,
#  'children\x92s': 836,
#  'lean': 837,
#  'work': 838,
#  'leonardo': 839,
#  'da': 840,
#  'vinci': 841,
#  'modern': 842,
#  'calligraphy': 843,
#  "beginner's": 844,
#  'learn': 845,
#  'hand': 846,
#  'brush': 847,
#  'liberty': 848,
#  'tyranny': 849,
#  'conservative': 850,
#  'manifesto': 851,
#  'bee': 852,
#  'blue': 853,
#  'truck': 854,
#  'fires': 855,
#  'everywhere': 856,
#  'looking': 857,
#  'alaska': 858,
#  'wins': 859,
#  'hell': 860,
#  'fate': 861,
#  'every': 862,
#  'person': 863,
#  'lived': 864,
#  'table': 865,
#  'gathering': 866,
#  'ahead': 867,
#  'maybe': 868,
#  'french': 869,
#  'vine': 870,
#  'inspirational': 871,
#  'quotes': 872,
#  'vines': 873,
#  'navy': 874,
#  'seal': 875,
#  'firsthand': 876,
#  'account': 877,
#  'killed': 878,
#  'osama': 879,
#  'bin': 880,
#  'laden': 881,
#  'intimate': 882,
#  'portrait': 883,
#  'old': 884,
#  'olive': 885,
#  'kitteridge': 886,
#  'option': 887,
#  'b': 888,
#  'facing': 889,
#  'adversity': 890,
#  'building': 891,
#  'joy': 892,
#  'origin': 893,
#  'robert': 894,
#  'langdon': 895,
#  'orphan': 896,
#  'deluxe': 897,
#  'need': 898,
#  'know': 899,
#  'stats': 900,
#  'puppy': 901,
#  'birthday': 902,
#  'paw': 903,
#  'patrol': 904,
#  'pilgrims': 905,
#  'patriots': 906,
#  "sarah's": 907,
#  'key': 908,
#  'hunt': 909,
#  'sh': 910,
#  't': 911,
#  'dad': 912,
#  'says': 913,
#  'ship': 914,
#  'fools': 915,
#  'selfish': 916,
#  'ruling': 917,
#  'bringing': 918,
#  'brink': 919,
#  'shred': 920,
#  'revolutionary': 921,
#  'weeks': 922,
#  'inches': 923,
#  'sizes': 924,
#  'miracles': 925,
#  'knowledge': 926,
#  'spiritual…': 927,
#  'super': 928,
#  'freakonomics': 929,
#  'global': 930,
#  'cooling': 931,
#  'patriotic': 932,
#  'prostitutes': 933,
#  'suicide': 934,
#  'bombers': 935,
#  'buy': 936,
#  'insurance': 937,
#  'switch': 938,
#  'sycamore': 939,
#  'row': 940,
#  'jake': 941,
#  'brigance': 942,
#  "doctor's": 943,
#  'designed': 944,
#  'results': 945,
#  'hour': 946,
#  'uncommon': 947,
#  'incredible': 948,
#  'sex': 949,
#  'superhuman': 950,
#  'alchemist': 951,
#  'amateur': 952,
#  'doomsday': 953,
#  'machine': 954,
#  'ultrahealthy': 955,
#  'losing': 956,
#  'preventing': 957,
#  'feeling': 958,
#  'now': 959,
#  'keeps': 960,
#  'score': 961,
#  'trauma': 962,
#  'basketball': 963,
#  'nba': 964,
#  'according': 965,
#  'sports': 966,
#  'guy': 967,
#  'casual': 968,
#  'vacancy': 969,
#  'china': 970,
#  'comprehensive': 971,
#  'nutrition': 972,
#  'conducted': 973,
#  'startling': 974,
#  'implications': 975,
#  'diet…': 976,
#  'confession': 977,
#  'constitution': 978,
#  'daily': 979,
#  'show': 980,
#  'jon': 981,
#  'stewart': 982,
#  "visitor's": 983,
#  'human': 984,
#  'dukan': 985,
#  'keep': 986,
#  'off': 987,
#  'elegance': 988,
#  'hedgehog': 989,
#  'express': 990,
#  'heartfelt': 991,
#  'mate': 992,
#  'getaway': 993,
#  'guardians': 994,
#  'guernsey': 995,
#  'literary': 996,
#  'potato': 997,
#  'peel': 998,
#  'pie': 999,
#  'society': 1000,
#  ...}

# %%
vocab_length = len(tokenizer.word_index) + 1

print("Vocabulary Length: ", vocab_length)
# Out:
# Vocabulary Length:  1160

# %%
names = tokenizer.texts_to_sequences(names)
names
# Out:
# [[49, 585, 586, 587],
#  [2, 9],
#  [343, 7, 37, 588, 589],
#  [590, 344],
#  [153, 345, 119, 262, 200, 201, 13],
#  [2, 95, 154, 2, 591, 346, 50],
#  [2, 77, 96, 2, 202, 203, 2, 204, 205, 2, 206, 207, 2, 95, 154],
#  [2, 592, 593, 2, 9],
#  [2, 594, 595, 155, 263, 120],
#  [2, 14, 347, 348, 2, 9],
#  [2, 14, 347, 348, 2, 9],
#  [2, 596, 349, 350, 351, 38, 597, 63, 598, 78, 352],
#  [2, 599, 7, 2, 121],
#  [2, 600, 79, 79, 601],
#  [602, 80, 603, 353, 80, 14, 39, 604, 605, 353, 119, 5, 606, 607, 354],
#  [97, 11, 3, 208, 209, 608, 11, 3, 264, 208, 355, 156, 609, 356],
#  [20, 14, 692, 38, 100, 101, 102, 20, 14],
#  [20, 14, 220, 693, 401, 694, 38, 100, 101, 102, 20, 14],
#  [20, 14, 695, 696, 38, 100, 101, 102, 20, 14],
#  [697, 376, 41, 42, 33],
#  [698, 165, 215, 25, 699, 358, 208, 11, 3, 165, 215, 11, 32],
#  [700, 1, 402, 155, 119, 39, 701, 403],
#  [66, 224, 128, 12, 702, 129, 8, 1, 225, 130, 67, 226, 404],
#  [66, 224, 128, 12, 703, 405, 65, 704, 122, 705, 4, 706, 707, 282],
#  [66, 123, 1, 406, 407, 214, 283, 131, 408, 67, 226, 409, 6],
#  [66, 123, 1, 406, 407, 214, 283, 131, 408, 67, 226, 409, 6],
#  [284, 81, 708],
#  [284, 81],
#  [410, 2, 121],
#  [410, 2, 121],
#  [709, 710, 37, 411, 285, 11, 3, 711, 32, 412, 712, 171, 713, 714],
#  [413],
#  [413],
#  [715, 414, 103, 286, 716, 1, 717, 718, 27, 28],
#  [719, 415, 416, 287],
#  [18, 19, 417],
#  [18, 19, 418, 3, 227, 18, 19, 53, 18, 19, 68, 17, 720, 6],
#  [18, 19, 68, 3, 54, 18, 19, 53, 18, 19, 68, 17],
#  [18, 19, 68, 3, 54, 18, 19, 53, 18, 19, 68, 17],
#  [18, 19, 53, 18, 19, 68, 18, 19, 417, 18, 19, 418],
#  [50, 721, 419, 415, 416, 287],
#  [64, 172],
#  [64, 172],
#  [64, 172],
#  [64, 172],
#  [64, 172],
#  [65, 343, 37, 722, 26],
#  [420, 35, 421, 3],
#  [77, 45, 422, 723, 724, 725, 423, 726],
#  [77, 96, 132, 85, 2, 77, 96, 2, 202, 203, 2, 204, 205, 2, 206, 207],
#  [77, 96, 132, 85, 2, 77, 96, 2, 202, 203, 2, 204, 205, 2, 206, 207],
#  [77, 96, 132, 85, 2, 77, 96, 2, 202, 203, 2, 204, 205, 2, 206, 207],
#  [424, 425, 426, 50],
#  [424, 425, 29, 727, 1, 728, 729, 12, 730, 16, 288],
#  [173, 83, 95],
#  [173, 83, 95],
#  [173, 83, 95],
#  [173, 83, 95],
#  [173, 83, 95],
#  [22, 51, 731, 2, 732, 427, 211, 733, 734, 10, 735],
#  [22,
#   428,
#   10,
#   429,
#   51,
#   430,
#   263,
#   119,
#   69,
#   4,
#   70,
#   431,
#   4,
#   122,
#   432,
#   69,
#   4,
#   433,
#   434,
#   84],
#  [22,
#   428,
#   10,
#   429,
#   51,
#   430,
#   263,
#   119,
#   69,
#   4,
#   70,
#   431,
#   4,
#   122,
#   432,
#   69,
#   4,
#   433,
#   434,
#   84],
#  [736, 737, 738, 739, 1, 435, 740, 104, 436, 741, 368, 360, 437, 742],
#  [55, 85, 743, 2, 9],
#  [55, 52, 744, 395],
#  [289, 745, 37, 16, 7],
#  [216, 22],
#  [216, 22],
#  [216, 22],
#  [36, 396, 174, 86, 290, 2, 438, 8, 56, 746, 37, 747, 436, 290, 290, 748],
#  [36, 63, 71, 228, 229, 105, 175, 230, 176],
#  [36, 63, 71, 228, 229, 105, 175, 230, 176],
#  [1, 169, 443, 404, 1, 955, 283, 956, 67, 957, 533, 958, 63, 959],
#  [1, 221, 960, 961, 280, 272, 221, 222, 962],
#  [1, 3, 963, 1, 964, 965, 1, 966, 967],
#  [1, 3, 534],
#  [1, 3, 534],
#  [1, 3, 225, 535],
#  [1, 3, 225, 535],
#  [1, 536, 246, 537, 244, 538, 539, 285, 540, 296, 541],
#  [1, 536, 246, 537, 244, 538, 539, 285, 540, 296, 541],
#  [1, 968, 969],
#  [1, 970, 75, 1, 267, 971, 75, 972, 476, 973, 158, 974, 975, 976],
#  [1, 542, 543, 130, 239, 10, 318, 8, 62, 544, 545],
#  [1, 542, 543, 130, 239, 10, 318, 8, 62, 544, 545],
#  [1, 977, 2, 9],
#  [1, 978, 350, 351],
#  [1, 979, 980, 981, 982, 473, 394, 1, 3, 2, 983, 8, 984, 423],
#  [1, 49, 323, 324],
#  [1, 49, 323, 324],
#  [1, 49, 323, 324],
#  [1, 985, 130, 546, 146, 67, 546, 986, 479, 987, 183],
#  [1, 988, 989],
#  [1, 247, 161, 248],
#  [1, 247, 161, 248],
#  [1, 247, 161, 248],
#  [1, 247, 161, 248],
#  [1, 147, 190, 191, 2, 120, 192],
#  [1, 147, 190, 191, 2, 120, 192],
#  [1, 147, 190, 191, 2, 120, 192],
#  [1, 147, 190, 191, 2, 120, 192],
#  [1, 147, 190, 191, 2, 120, 192],
#  [1, 147, 5, 47, 15, 990, 991, 354, 10, 992],
#  [1, 148, 149, 2, 110, 8, 31, 76, 2, 150, 109, 3],
#  [1, 148, 149, 2, 110, 8, 31, 76, 2, 150, 109, 3],
#  [1, 148, 149, 2, 110, 8, 31, 76, 2, 150, 109, 3],
#  [1, 148, 149, 2, 110, 8, 31, 76, 2, 150, 109, 3],
#  [1, 148, 149, 2, 110, 8, 31, 76, 2, 150, 109, 3],
#  [1, 148, 149, 2, 110, 8, 31, 76, 2, 150, 109, 3],
#  [1, 993],
#  [1, 22, 312],
#  [1, 22, 312],
#  [1, 22, 69, 547, 548, 549, 151, 53],
#  [1, 22, 69, 547, 548, 549, 151, 53],
#  [1, 22, 69, 550, 50, 151, 17],
#  [1, 22, 69, 550, 50, 151],
#  [1, 22, 551, 552, 151, 17],
#  [1, 22, 551, 552, 151, 17],
#  [1, 289, 56, 302, 3],
#  [1, 289, 56, 302, 3],
#  [1, 553, 2, 9, 554, 555, 556],
#  [1, 553, 2, 9, 554, 555, 556],
#  [1, 63, 325],
#  [1, 63, 325],
#  [1, 63, 325],
#  [1, 994, 2, 9],
#  [1, 995, 996, 997, 998, 999, 1000],
#  [1, 1001, 398],
#  [1, 1002, 1, 519, 1003, 1004, 29, 1005, 1006],
#  [1, 1007, 366, 193],
#  [1, 152],
#  [1, 152],
#  [1, 152],
#  [1, 152],
#  [1, 287, 1008, 189, 145, 3],
#  [1, 43, 44],
#  [1, 43, 44, 3],
#  [1, 43, 44, 3],
#  [1, 43, 44, 53, 132, 85],
#  [1, 43, 44, 53, 132, 85],
#  [1, 326, 7, 327, 328],
#  [103, 223, 57, 70],
#  [1149, 246, 159, 224, 246, 1150, 12, 176, 152, 1151, 1152],
#  [223, 38, 331, 1153, 1154, 1155, 1156],
#  [1157, 21, 3, 399, 378, 53],
#  [475, 65, 213, 37, 468, 126, 1158, 262],
#  [199],
#  [199],
#  [199],
#  [199],
#  [199],
#  [1159, 401, 41, 42, 33, 3],
#  [4, 70, 259, 15, 51, 260, 10, 261, 174, 62, 153, 7],
#  [4, 70, 259, 15, 51, 260, 10, 261, 174, 62, 153, 7],
#  [4, 70, 259, 15, 51, 260, 10, 261, 174, 62, 153, 7],
#  [4, 70, 259, 15, 51, 260, 10, 261, 174, 62, 153, 7]]

# %%
max_seq_length = np.max(list(map(lambda name: len(name), names)))
print("Max Sequence Length:", max_seq_length)
# Out:
# Max Sequence Length: 20

# %%
names = pad_sequences(names, maxlen=max_seq_length, padding='post')
names
# Out:
# array([[ 49, 585, 586, ...,   0,   0,   0],
#        [  2,   9,   0, ...,   0,   0,   0],
#        [343,   7,  37, ...,   0,   0,   0],
#        ...,
#        [  4,  70, 259, ...,   0,   0,   0],
#        [  4,  70, 259, ...,   0,   0,   0],
#        [  4,  70, 259, ...,   0,   0,   0]], dtype=int32)

# %%
data = data.drop('Name', axis=1)
data
# Out:
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 6 columns]

# %% [markdown]
# ### Encoding Other Features

# %%
genre_mapping = {'Non Fiction': 0, 'Fiction': 1}

data['Genre'] = data['Genre'].replace(genre_mapping)
# Out:
# /tmp/ipykernel_173/2413103998.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Genre'] = data['Genre'].replace(genre_mapping)

# %%
data
# Out:
#                        Author  User Rating  Reviews  Price  Year  Genre
# 0                    JJ Smith          4.7    17350      8  2016      0
# 1                Stephen King          4.6     2052     22  2011      1
# 2          Jordan B. Peterson          4.7    18979     15  2018      0
# 3               George Orwell          4.7    21424      6  2017      1
# 4    National Geographic Kids          4.8     7665     12  2019      0
# ..                        ...          ...      ...    ...   ...    ...
# 545               Jeff Kinney          4.9     9413      8  2019      1
# 546               Jen Sincero          4.7    14331      8  2016      0
# 547               Jen Sincero          4.7    14331      8  2017      0
# 548               Jen Sincero          4.7    14331      8  2018      0
# 549               Jen Sincero          4.7    14331      8  2019      0
#
# [550 rows x 6 columns]

# %%
print("Number of unique authors: ", len(data['Author'].unique()))
# Out:
# Number of unique authors:  248

# %%
def onehot_encode(df, column, prefix):
    df = df.copy()
    dummies = pd.get_dummies(df[column], prefix=prefix)
    df = pd.concat([df, dummies], axis=1)
    df = df.drop(column, axis=1)
    return df

# %%
data = onehot_encode(data, 'Author', 'auth')
data
# Out:
#      User Rating  Reviews  Price  Year  Genre  auth_Abraham Verghese  \
# 0            4.7    17350      8  2016      0                  False
# 1            4.6     2052     22  2011      1                  False
# 2            4.7    18979     15  2018      0                  False
# 3            4.7    21424      6  2017      1                  False
# 4            4.8     7665     12  2019      0                  False
# ..           ...      ...    ...   ...    ...                    ...
# 545          4.9     9413      8  2019      1                  False
# 546          4.7    14331      8  2016      0                  False
# 547          4.7    14331      8  2017      0                  False
# 548          4.7    14331      8  2018      0                  False
# 549          4.7    14331      8  2019      0                  False
#
#      auth_Adam Gasiewski  auth_Adam Mansbach  auth_Adir Levy  \
# 0                  False               False           False
# 1                  False               False           False
# 2                  False               False           False
# 3                  False               False           False
# 4                  False               False           False
# ..                   ...                 ...             ...
# 545                False               False           False
# 546                False               False           False
# 547                False               False           False
# 548                False               False           False
# 549                False               False           False
#
#      auth_Admiral William H. McRaven  ...  auth_Todd Burpo  auth_Tony Hsieh  \
# 0                              False  ...            False            False
# 1                              False  ...            False            False
# 2                              False  ...            False            False
# 3                              False  ...            False            False
# 4                              False  ...            False            False
# ..                               ...  ...              ...              ...
# 545                            False  ...            False            False
# 546                            False  ...            False            False
# 547                            False  ...            False            False
# 548                            False  ...            False            False
# 549                            False  ...            False            False
#
#      auth_Tucker Carlson  auth_Veronica Roth  auth_W. Cleon Skousen  \
# 0                  False               False                  False
# 1                  False               False                  False
# 2                  False               False                  False
# 3                  False               False                  False
# 4                  False               False                  False
# ..                   ...                 ...                    ...
# 545                False               False                  False
# 546                False               False                  False
# 547                False               False                  False
# 548                False               False                  False
# 549                False               False                  False
#
#      auth_Walter Isaacson  auth_William Davis  auth_William P. Young  \
# 0                   False               False                  False
# 1                   False               False                  False
# 2                   False               False                  False
# 3                   False               False                  False
# 4                   False               False                  False
# ..                    ...                 ...                    ...
# 545                 False               False                  False
# 546                 False               False                  False
# 547                 False               False                  False
# 548                 False               False                  False
# 549                 False               False                  False
#
#      auth_Wizards RPG Team  auth_Zhi Gang Sha
# 0                    False              False
# 1                    False              False
# 2                    False              False
# 3                    False              False
# 4                    False              False
# ..                     ...                ...
# 545                  False              False
# 546                  False              False
# 547                  False              False
# 548                  False              False
# 549                  False              False
#
# [550 rows x 253 columns]

# %% [markdown]
# ### Splitting/Scaling

# %%
y = data['Genre'].copy()
X = data.drop('Genre', axis=1).copy()

# %%
scaler = StandardScaler()

X = scaler.fit_transform(X)

# %%
names_train, names_test, X_train, X_test, y_train, y_test = train_test_split(names, X, y, train_size=0.7, random_state=100)

# %%
len(names_train), len(X_train)
# Out:
# (385, 385)

# %% [markdown]
# ### Modelling/Training

# %%
names.shape, X.shape
# Out:
# ((550, 20), (550, 252))

# %%
embedding_dim = 64

# Name Features
name_input = tf.keras.Input(shape=(20, ), name='name_input')

embedding = tf.keras.layers.Embedding(
    input_dim = vocab_length,
    output_dim = embedding_dim,
    input_length = max_seq_length,
    name = 'name_embedding'
)(name_input)

print(embedding.shape)

name_flatten = tf.keras.layers.Flatten(name='name_flatten')(embedding)

print(name_flatten.shape)
# Out:
# (None, 20, 64)
# (None, 1280)

# %%
# Other features
other_input = tf.keras.Input(shape=(252, ), name='other_input')

hidden_1 = tf.keras.layers.Dense(256, activation='relu', name='other_dense_1')(other_input)
hidden_2 = tf.keras.layers.Dense(256, activation='relu', name='other_dense_2')(hidden_1)

# Concatenate and output
concat = tf.keras.layers.concatenate([name_flatten, hidden_2], name='concatenate')

outputs = tf.keras.layers.Dense(1, activation='sigmoid', name='output')(concat)

model = tf.keras.Model(inputs=[name_input, other_input], outputs=outputs)

print(model.summary())

tf.keras.utils.plot_model(model)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  name_input (InputLayer)        [(None, 20)]         0           []
#
#  other_input (InputLayer)       [(None, 252)]        0           []
#
#  name_embedding (Embedding)     (None, 20, 64)       74240       ['name_input[0][0]']
#
#  other_dense_1 (Dense)          (None, 256)          64768       ['other_input[0][0]']
#
#  name_flatten (Flatten)         (None, 1280)         0           ['name_embedding[0][0]']
#
#  other_dense_2 (Dense)          (None, 256)          65792       ['other_dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 1536)         0           ['name_flatten[0][0]',
#                                                                   'other_dense_2[0][0]']
#
#  output (Dense)                 (None, 1)            1537        ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 206,337
# Trainable params: 206,337
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
y_train
# Out:
# 471    0
# 46     1
# 50     0
# 365    1
# 169    0
#       ..
# 526    0
# 53     1
# 350    1
# 79     1
# 520    1
# Name: Genre, Length: 385, dtype: int64

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics = [
        'accuracy',
        tf.keras.metrics.AUC(name='auc')
    ]
)

batch_size = 32
epochs = 100

history = model.fit(
    [names_train, X_train],
    y_train,
    validation_split=0.12,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                         patience=3,
                                        restore_best_weights=True)
    ]
)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 2s 52ms/step - loss: 0.6466 - accuracy: 0.6095 - auc: 0.7085 - val_loss: 0.5873 - val_accuracy: 0.7660 - val_auc: 0.8111
# Epoch 2/100
# 11/11 [==============================] - 0s 15ms/step - loss: 0.4373 - accuracy: 0.9527 - auc: 0.9937 - val_loss: 0.4886 - val_accuracy: 0.8723 - val_auc: 0.8675
# Epoch 3/100
# 11/11 [==============================] - 0s 14ms/step - loss: 0.2503 - accuracy: 0.9882 - auc: 0.9997 - val_loss: 0.3836 - val_accuracy: 0.8511 - val_auc: 0.8919
# Epoch 4/100
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0984 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.3286 - val_accuracy: 0.8511 - val_auc: 0.9098
# Epoch 5/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0280 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.3096 - val_accuracy: 0.8298 - val_auc: 0.9211
# Epoch 6/100
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0092 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.3139 - val_accuracy: 0.8298 - val_auc: 0.9211
# Epoch 7/100
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0040 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.3222 - val_accuracy: 0.8511 - val_auc: 0.9182
# Epoch 8/100
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0025 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.3262 - val_accuracy: 0.8511 - val_auc: 0.9173

# %% [markdown]
# ### Results

# %%
model.evaluate([names_test, X_test], y_test)
# Out:
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2705 - accuracy: 0.8667 - auc: 0.9431
# [0.27049797773361206, 0.8666666746139526, 0.9430714845657349]

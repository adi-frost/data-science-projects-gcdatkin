# %% [markdown]
# ## Human Activity Recognition
#
# Given *data about human movement and activity*, let's try to predict the **activity** that a given human is peforming.
#
# We will use a Tensorflow ANN to make our predictions.
#
# Data source: https://www.kaggle.com/datasets/uciml/human-activity-recognition-with-smartphones

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler

import tensorflow as tf
# Out:
# 2025-06-01 11:16:17.031877: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
tf.random.set_seed(4445444)

# %%
train_df = pd.read_csv('archive/train.csv')
test_df = pd.read_csv('archive/test.csv')

# %%
train_df
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# 1            -0.998245         -0.975300         -0.960322         -0.998807
# 2            -0.995380         -0.967187         -0.978944         -0.996520
# 3            -0.996091         -0.983403         -0.990675         -0.997099
# 4            -0.998139         -0.980817         -0.990482         -0.998321
# ...                ...               ...               ...               ...
# 7347         -0.195387          0.039905          0.077078         -0.282301
# 7348         -0.235309          0.004816          0.059280         -0.322552
# 7349         -0.218218         -0.103822          0.274533         -0.304515
# 7350         -0.219139         -0.111412          0.268893         -0.310487
# 7351         -0.269270         -0.087212          0.177404         -0.377404
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 0            -0.983185         -0.923527         -0.934724  ...
# 1            -0.974914         -0.957686         -0.943068  ...
# 2            -0.963668         -0.977469         -0.938692  ...
# 3            -0.982750         -0.989302         -0.938692  ...
# 4            -0.979672         -0.990441         -0.942469  ...
# ...                ...               ...               ...  ...
# 7347          0.043616          0.060410          0.210795  ...
# 7348         -0.029456          0.080585          0.117440  ...
# 7349         -0.098913          0.332584          0.043999  ...
# 7350         -0.068200          0.319473          0.101702  ...
# 7351         -0.038678          0.229430          0.269013  ...
#
#       fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# 0                           -0.710304                    -0.112754
# 1                           -0.861499                     0.053477
# 2                           -0.760104                    -0.118559
# 3                           -0.482845                    -0.036788
# 4                           -0.699205                     0.123320
# ...                               ...                          ...
# 7347                        -0.880324                    -0.190437
# 7348                        -0.680744                     0.064907
# 7349                        -0.304029                     0.052806
# 7350                        -0.344314                    -0.101360
# 7351                        -0.740738                    -0.280088
#
#       angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# 0                                 0.030400                         -0.464761
# 1                                -0.007435                         -0.732626
# 2                                 0.177899                          0.100699
# 3                                -0.012892                          0.640011
# 4                                 0.122542                          0.693578
# ...                                    ...                               ...
# 7347                              0.829718                          0.206972
# 7348                              0.875679                         -0.879033
# 7349                             -0.266724                          0.864404
# 7350                              0.700740                          0.936674
# 7351                             -0.007739                         -0.056088
#
#       angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# 0                                -0.018446             -0.841247
# 1                                 0.703511             -0.844788
# 2                                 0.808529             -0.848933
# 3                                -0.485366             -0.848649
# 4                                -0.615971             -0.847865
# ...                                    ...                   ...
# 7347                             -0.425619             -0.791883
# 7348                              0.400219             -0.771840
# 7349                              0.701169             -0.779133
# 7350                             -0.589479             -0.785181
# 7351                             -0.616956             -0.783267
#
#       angle(Y,gravityMean)  angle(Z,gravityMean)  subject          Activity
# 0                 0.179941             -0.058627        1          STANDING
# 1                 0.180289             -0.054317        1          STANDING
# 2                 0.180637             -0.049118        1          STANDING
# 3                 0.181935             -0.047663        1          STANDING
# 4                 0.185151             -0.043892        1          STANDING
# ...                    ...                   ...      ...               ...
# 7347              0.238604              0.049819       30  WALKING_UPSTAIRS
# 7348              0.252676              0.050053       30  WALKING_UPSTAIRS
# 7349              0.249145              0.040811       30  WALKING_UPSTAIRS
# 7350              0.246432              0.025339       30  WALKING_UPSTAIRS
# 7351              0.246809              0.036695       30  WALKING_UPSTAIRS
#
# [7352 rows x 563 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
train_df.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# 25%           -0.992754         -0.978129         -0.980233         -0.993591
# 50%           -0.946196         -0.851897         -0.859365         -0.950709
# 75%           -0.242813         -0.034231         -0.262415         -0.292680
# max            1.000000          0.916238          1.000000          1.000000
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       7352.000000       7352.000000       7352.000000  ...
# mean          -0.526907         -0.606150         -0.468604  ...
# std            0.485942          0.414122          0.544547  ...
# min           -1.000000         -1.000000         -1.000000  ...
# 25%           -0.978162         -0.980251         -0.936219  ...
# 50%           -0.857328         -0.857143         -0.881637  ...
# 75%           -0.066701         -0.265671         -0.017129  ...
# max            0.967664          1.000000          1.000000  ...
#
#        fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# count                      7352.000000                      7352.000000
# mean                         -0.307009                        -0.625294
# std                           0.321011                         0.307584
# min                          -0.995357                        -0.999765
# 25%                          -0.542602                        -0.845573
# 50%                          -0.343685                        -0.711692
# 75%                          -0.126979                        -0.503878
# max                           0.989538                         0.956845
#
#        angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# count                  7352.000000                           7352.000000
# mean                      0.008684                              0.002186
# std                       0.336787                              0.448306
# min                      -0.976580                             -1.000000
# 25%                      -0.121527                             -0.289549
# 50%                       0.009509                              0.008943
# 75%                       0.150865                              0.292861
# max                       1.000000                              1.000000
#
#        angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# count                       7352.000000                           7352.000000
# mean                           0.008726                             -0.005981
# std                            0.608303                              0.477975
# min                           -1.000000                             -1.000000
# 25%                           -0.482273                             -0.376341
# 50%                            0.008735                             -0.000368
# 75%                            0.506187                              0.359368
# max                            0.998702                              0.996078
#
#        angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# count           7352.000000           7352.000000           7352.000000
# mean              -0.489547              0.058593             -0.056515
# std                0.511807              0.297480              0.279122
# min               -1.000000             -1.000000             -1.000000
# 25%               -0.812065             -0.017885             -0.143414
# 50%               -0.709417              0.182071              0.003181
# 75%               -0.509079              0.248353              0.107659
# max                1.000000              0.478157              1.000000
#
#            subject
# count  7352.000000
# mean     17.413085
# std       8.975143
# min       1.000000
# 25%       8.000000
# 50%      19.000000
# 75%      26.000000
# max      30.000000
#
# [8 rows x 562 columns]

# %% [markdown]
# ### Preprocessing

# %%
print("Train set missing values: ", train_df.isna().sum().sum())
# Out:
# Train set missing values:  0

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2947 entries, 0 to 2946
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 12.7+ MB

# %%
print("Train set missing values: ", train_df.isna().sum().sum())
# Out:
# Train set missing values:  0

# %% [markdown]
# #### Splitting Data

# %%
y_train = train_df['Activity'].copy()
X_train = train_df.drop('Activity', axis=1).copy()

# %%
y_test = test_df['Activity'].copy()
X_test = test_df.drop('Activity', axis=1).copy()

# %% [markdown]
# #### Encoding Labels

# %%
y_train.value_counts()
# Out:
# Activity
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: count, dtype: int64

# %%
num_classes = 6

label_encoder = LabelEncoder()
label_encoder.fit(y_train)

y_train = label_encoder.transform(y_train)
y_test = label_encoder.transform(y_test)

# %% [markdown]
# #### Scaling Data

# %%
scaler = StandardScaler()
# scaler = MinMaxScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape, X_test.shape
# Out:
# ((7352, 562), (2947, 562))

# %% [markdown]
# ### Modeling/Training

# %%
inputs = tf.keras.Input(shape=(X_train.shape[1], ))
x = tf.keras.layers.Dense(64, activation='relu')(inputs)
x = tf.keras.layers.Dense(64, activation='relu')(x)
outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)
# Out:
# 2025-06-01 11:16:20.653518: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 562)]             0
#
#  dense (Dense)               (None, 64)                36032
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 40,582
# Trainable params: 40,582
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 32
epochs = 25

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size = batch_size,
    epochs = epochs,
    callbacks = [
        tf.keras.callbacks.ModelCheckpoint('./model.h5', save_best_only=True),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.1,
            patience=1
        )
    ]
)
# Out:
# Epoch 1/25
# 184/184 [==============================] - 1s 5ms/step - loss: 0.2910 - accuracy: 0.8920 - val_loss: 0.1568 - val_accuracy: 0.9327 - lr: 0.0010
# Epoch 2/25
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0871 - accuracy: 0.9684 - val_loss: 0.1734 - val_accuracy: 0.9307 - lr: 0.0010
# Epoch 3/25
# 184/184 [==============================] - 1s 5ms/step - loss: 0.0493 - accuracy: 0.9840 - val_loss: 0.1520 - val_accuracy: 0.9415 - lr: 1.0000e-04
# Epoch 4/25
# 184/184 [==============================] - 1s 5ms/step - loss: 0.0426 - accuracy: 0.9862 - val_loss: 0.1599 - val_accuracy: 0.9436 - lr: 1.0000e-04
# Epoch 5/25
# 184/184 [==============================] - 1s 5ms/step - loss: 0.0403 - accuracy: 0.9869 - val_loss: 0.1477 - val_accuracy: 0.9409 - lr: 1.0000e-05
# Epoch 6/25
# 184/184 [==============================] - 1s 5ms/step - loss: 0.0395 - accuracy: 0.9876 - val_loss: 0.1468 - val_accuracy: 0.9409 - lr: 1.0000e-05
# Epoch 7/25
# 184/184 [==============================] - 1s 5ms/step - loss: 0.0392 - accuracy: 0.9876 - val_loss: 0.1463 - val_accuracy: 0.9402 - lr: 1.0000e-05
# Epoch 8/25
# 184/184 [==============================] - 1s 5ms/step - loss: 0.0389 - accuracy: 0.9878 - val_loss: 0.1452 - val_accuracy: 0.9395 - lr: 1.0000e-05
# Epoch 9/25
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0386 - accuracy: 0.9876 - val_loss: 0.1445 - val_accuracy: 0.9395 - lr: 1.0000e-05
# Epoch 10/25
# 184/184 [==============================] - 1s 5ms/step - loss: 0.0383 - accuracy: 0.9878 - val_loss: 0.1440 - val_accuracy: 0.9388 - lr: 1.0000e-05
# Epoch 11/25
# 184/184 [==============================] - 0s 3ms/step - loss: 0.0380 - accuracy: 0.9883 - val_loss: 0.1448 - val_accuracy: 0.9395 - lr: 1.0000e-05
# Epoch 12/25
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0375 - accuracy: 0.9883 - val_loss: 0.1447 - val_accuracy: 0.9395 - lr: 1.0000e-06
# Epoch 13/25
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.1447 - val_accuracy: 0.9395 - lr: 1.0000e-07
# Epoch 14/25
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.1447 - val_accuracy: 0.9395 - lr: 1.0000e-08
# Epoch 15/25
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.1447 - val_accuracy: 0.9395 - lr: 1.0000e-09
# Epoch 16/25
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.1447 - val_accuracy: 0.9395 - lr: 1.0000e-10
# Epoch 17/25
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.1447 - val_accuracy: 0.9395 - lr: 1.0000e-11
# Epoch 18/25
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.1447 - val_accuracy: 0.9395 - lr: 1.0000e-12
# Epoch 19/25
# 184/184 [==============================] - 0s 3ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.1447 - val_accuracy: 0.9395 - lr: 1.0000e-13
# Epoch 20/25
# 184/184 [==============================] - 0s 3ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.1447 - val_accuracy: 0.9395 - lr: 1.0000e-14
# Epoch 21/25
# 184/184 [==============================] - 0s 3ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.1447 - val_accuracy: 0.9395 - lr: 1.0000e-15
# Epoch 22/25
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.1447 - val_accuracy: 0.9395 - lr: 1.0000e-16
# Epoch 23/25
# 184/184 [==============================] - 0s 3ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.1447 - val_accuracy: 0.9395 - lr: 1.0000e-17
# Epoch 24/25
# 184/184 [==============================] - 0s 3ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.1447 - val_accuracy: 0.9395 - lr: 1.0000e-18
# Epoch 25/25
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.1447 - val_accuracy: 0.9395 - lr: 1.0000e-19

# %% [markdown]
# ### Results

# %%
plt.figure(figsize=(7, 7))

epochs_range = range(epochs)
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(
    epochs_range,
    train_loss,
    label='Training Loss'
)

plt.plot(
    epochs_range,
    val_loss,
    label='Validation Loss'
)

plt.legend()
plt.title("Loss Over Time")
plt.show()

# %%
model.load_weights('./model.h5')

# %%
model.evaluate(X_test, y_test)
# Out:
# 93/93 [==============================] - 0s 4ms/step - loss: 0.2172 - accuracy: 0.9308
# [0.21720817685127258, 0.9307770729064941]

# %% [markdown]
# Model Accuracy if Standard scaling applied: 93.08%
#
# Model Accuracy if MinMax scaling applied: 92.2%

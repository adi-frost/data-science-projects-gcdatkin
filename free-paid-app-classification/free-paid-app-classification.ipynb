# %% [markdown]
# ## 📱 Free/Paid App Classification
#
# Given *data about Apple store app rankings*, let's try to predict whether a given app will be **free** or not.
#
# We will use a logistic regression model to make our predictions.
#
# Data source: https://www.kaggle.com/datasets/iamsk7/apple-store-ranks-2019

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression, LogisticRegressionCV

# %%
data = pd.read_csv('ranks.csv')
data
# Out:
#              appid        date  category      feed  \
# 0        691828408  2019-11-30      5000      free
# 1       1458072671  2019-11-30      5000      free
# 2       1448327606  2019-11-30      5000      free
# 3       1472502819  2019-11-30      5000      free
# 4       1142110895  2019-11-30      5000      free
# ...            ...         ...       ...       ...
# 112622  1142972033  2019-12-06      5000  grossing
# 112623  1196953001  2019-12-06      5000  grossing
# 112624   487115059  2019-12-06      5000  grossing
# 112625   493145008  2019-12-06      5000  grossing
# 112626  1468605335  2019-12-06      5000  grossing
#
#                                  name  \
# 0                         微视-短视频创作与分享
# 1                           剪映 - 轻而易剪
# 2                               刷宝短视频
# 3                               快手极速版
# 4                               抖音短视频
# ...                               ...
# 112622             漫画岛-快看二次元动漫漫画神器APP
# 112623              SuperPads打击垫：音乐魔器
# 112624             7M即时比分-足球探索预测分析体育网
# 112625  Headspace: Meditation & Sleep
# 112626                草莓交友-同城视频聊天交友约会
#
#                                            publisher  price  ranking  change  \
# 0       Tencent Technology (Beijing) Company Limited    0.0        1      12
# 1                                        深圳市脸萌科技有限公司    0.0        2      -1
# 2                                       成都力奥文化传播有限公司    0.0        3      -1
# 3                                               华艺汇龙    0.0        4      -1
# 4       Beijing Microlive Vision Technology Co., Ltd    0.0        5      -1
# ...                                              ...    ...      ...     ...
# 112622                                  上海元聚网络科技有限公司    0.0      634    9999
# 112623      Opala Studios Solucoes Tecnologicas Ltda    0.0      635    9999
# 112624          IEXIN Technology Development Limited    0.0      636    9999
# 112625                                Headspace Inc.    0.0      637    9999
# 112626                                      siqi xie    0.0      638    9999
#
#         sub_ranking  sub_change  comment_rating  comment_num  keyword_cover
# 0                 1           5             4.5       124000          17503
# 1                 2          -1             4.9       632000          19978
# 2                 3          -1             4.8       599000           6759
# 3                 4          -1             4.9       228000          38549
# 4                 5          -1             4.9     23870000          21441
# ...             ...         ...             ...          ...            ...
# 112622           62           3             4.6         2747           5457
# 112623           26           4             4.7        30500           5297
# 112624           19           0             4.9         3552          17844
# 112625           20           3             4.9         3658           1968
# 112626           89          17             5.0         4244           6180
#
# [112627 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112627 entries, 0 to 112626
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   appid           112627 non-null  int64
#  1   date            112627 non-null  object
#  2   category        112627 non-null  int64
#  3   feed            112627 non-null  object
#  4   name            112627 non-null  object
#  5   publisher       112627 non-null  object
#  6   price           112627 non-null  float64
#  7   ranking         112627 non-null  int64
#  8   change          112627 non-null  int64
#  9   sub_ranking     112627 non-null  int64
#  10  sub_change      112627 non-null  int64
#  11  comment_rating  112627 non-null  float64
#  12  comment_num     112627 non-null  int64
#  13  keyword_cover   112627 non-null  int64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 12.0+ MB

# %% [markdown]
# ### Cleaning

# %%
unneeded_columns = ['appid', 'name', 'publisher']

data.drop(unneeded_columns, axis=1, inplace=True)

# %%
data = data.replace(-1, np.NaN)

# %%
data.isna().sum()
# Out:
# date                 0
# category             0
# feed                 0
# price                0
# ranking              0
# change             818
# sub_ranking          0
# sub_change        8209
# comment_rating       0
# comment_num          0
# keyword_cover        0
# dtype: int64

# %%
for column in ['change', 'sub_change']:
    data[column] = data[column].fillna(data[column].mean())

# %%
print("Total missing values: ", data.isna().sum().sum())
# Out:
# Total missing values:  0

# %% [markdown]
# ### Feature Engineering

# %%
data
# Out:
#               date  category      feed  price  ranking       change  \
# 0       2019-11-30      5000      free    0.0        1    12.000000
# 1       2019-11-30      5000      free    0.0        2   210.013711
# 2       2019-11-30      5000      free    0.0        3   210.013711
# 3       2019-11-30      5000      free    0.0        4   210.013711
# 4       2019-11-30      5000      free    0.0        5   210.013711
# ...            ...       ...       ...    ...      ...          ...
# 112622  2019-12-06      5000  grossing    0.0      634  9999.000000
# 112623  2019-12-06      5000  grossing    0.0      635  9999.000000
# 112624  2019-12-06      5000  grossing    0.0      636  9999.000000
# 112625  2019-12-06      5000  grossing    0.0      637  9999.000000
# 112626  2019-12-06      5000  grossing    0.0      638  9999.000000
#
#         sub_ranking  sub_change  comment_rating  comment_num  keyword_cover
# 0                 1    5.000000             4.5       124000          17503
# 1                 2   52.753089             4.9       632000          19978
# 2                 3   52.753089             4.8       599000           6759
# 3                 4   52.753089             4.9       228000          38549
# 4                 5   52.753089             4.9     23870000          21441
# ...             ...         ...             ...          ...            ...
# 112622           62    3.000000             4.6         2747           5457
# 112623           26    4.000000             4.7        30500           5297
# 112624           19    0.000000             4.9         3552          17844
# 112625           20    3.000000             4.9         3658           1968
# 112626           89   17.000000             5.0         4244           6180
#
# [112627 rows x 11 columns]

# %%
data['year'] = data['date'].apply(lambda x: int(x[0:4]))
data['month'] = data['date'].apply(lambda x: int(x[5:7]))
data['day'] = data['date'].apply(lambda x: int(x[-2:]))

data = data.drop('date', axis=1)

# %%
data['category'].unique()
# Out:
# array([5000, 6000, 6001, 6002, 6003, 6004, 6005, 6006, 6007, 6008, 6009,
#        6010, 6011, 6012, 6013, 6015, 6016, 6017, 6018, 6020, 6021, 6023,
#        6024, 6061])

# %%
category_dummies = pd.get_dummies(data['category'], prefix='cat')

data = pd.concat([data, category_dummies], axis=1)
data = data.drop('category', axis=1)

# %% [markdown]
# ### Encoding Labels
#
# In fact, let's only worry about examples that are either *free or paid*.

# %%
data['feed'].value_counts()
# Out:
# feed
# free        40677
# paid        36709
# grossing    35241
# Name: count, dtype: int64

# %%
grossing_indices = data.query('feed == "grossing"').index

data = data.drop(grossing_indices, axis=0)

# %%
data = data.reset_index(drop=True)

# %%
data
# Out:
#        feed  price  ranking       change  sub_ranking  sub_change  \
# 0      free    0.0        1    12.000000            1    5.000000
# 1      free    0.0        2   210.013711            2   52.753089
# 2      free    0.0        3   210.013711            3   52.753089
# 3      free    0.0        4   210.013711            4   52.753089
# 4      free    0.0        5   210.013711            5   52.753089
# ...     ...    ...      ...          ...          ...         ...
# 77381  paid    6.0      786  9999.000000          128   35.000000
# 77382  paid    1.0      787   -79.000000           32   -4.000000
# 77383  paid   25.0      788   -72.000000           22   -2.000000
# 77384  paid   12.0      789   -54.000000           84   -7.000000
# 77385  paid    1.0      790   -80.000000          159  -12.000000
#
#        comment_rating  comment_num  keyword_cover  year  ...  cat_6013  \
# 0                 4.5       124000          17503  2019  ...     False
# 1                 4.9       632000          19978  2019  ...     False
# 2                 4.8       599000           6759  2019  ...     False
# 3                 4.9       228000          38549  2019  ...     False
# 4                 4.9     23870000          21441  2019  ...     False
# ...               ...          ...            ...   ...  ...       ...
# 77381             0.0            0            685  2019  ...     False
# 77382             0.0            0           1142  2019  ...     False
# 77383             4.5          132           1240  2019  ...     False
# 77384             4.8          744            477  2019  ...     False
# 77385             4.0           15            192  2019  ...     False
#
#        cat_6015  cat_6016  cat_6017  cat_6018  cat_6020  cat_6021  cat_6023  \
# 0         False     False     False     False     False     False     False
# 1         False     False     False     False     False     False     False
# 2         False     False     False     False     False     False     False
# 3         False     False     False     False     False     False     False
# 4         False     False     False     False     False     False     False
# ...         ...       ...       ...       ...       ...       ...       ...
# 77381     False     False     False     False     False     False     False
# 77382     False     False     False     False     False     False     False
# 77383     False     False     False     False     False     False     False
# 77384     False     False     False     False     False     False     False
# 77385     False     False     False     False     False     False     False
#
#        cat_6024  cat_6061
# 0         False     False
# 1         False     False
# 2         False     False
# 3         False     False
# 4         False     False
# ...         ...       ...
# 77381     False     False
# 77382     False     False
# 77383     False     False
# 77384     False     False
# 77385     False     False
#
# [77386 rows x 36 columns]

# %%
print("Class Distribution:")
print(data['feed'].value_counts() / len(data['feed']))
# Out:
# Class Distribution:
# feed
# free    0.525638
# paid    0.474362
# Name: count, dtype: float64

# %%
label_mapping = {'free': 0, 'paid': 1}

data['feed'] = data['feed'].replace(label_mapping)
# Out:
# /tmp/ipykernel_9012/1783814060.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['feed'] = data['feed'].replace(label_mapping)

# %%
data
# Out:
#        feed  price  ranking       change  sub_ranking  sub_change  \
# 0         0    0.0        1    12.000000            1    5.000000
# 1         0    0.0        2   210.013711            2   52.753089
# 2         0    0.0        3   210.013711            3   52.753089
# 3         0    0.0        4   210.013711            4   52.753089
# 4         0    0.0        5   210.013711            5   52.753089
# ...     ...    ...      ...          ...          ...         ...
# 77381     1    6.0      786  9999.000000          128   35.000000
# 77382     1    1.0      787   -79.000000           32   -4.000000
# 77383     1   25.0      788   -72.000000           22   -2.000000
# 77384     1   12.0      789   -54.000000           84   -7.000000
# 77385     1    1.0      790   -80.000000          159  -12.000000
#
#        comment_rating  comment_num  keyword_cover  year  ...  cat_6013  \
# 0                 4.5       124000          17503  2019  ...     False
# 1                 4.9       632000          19978  2019  ...     False
# 2                 4.8       599000           6759  2019  ...     False
# 3                 4.9       228000          38549  2019  ...     False
# 4                 4.9     23870000          21441  2019  ...     False
# ...               ...          ...            ...   ...  ...       ...
# 77381             0.0            0            685  2019  ...     False
# 77382             0.0            0           1142  2019  ...     False
# 77383             4.5          132           1240  2019  ...     False
# 77384             4.8          744            477  2019  ...     False
# 77385             4.0           15            192  2019  ...     False
#
#        cat_6015  cat_6016  cat_6017  cat_6018  cat_6020  cat_6021  cat_6023  \
# 0         False     False     False     False     False     False     False
# 1         False     False     False     False     False     False     False
# 2         False     False     False     False     False     False     False
# 3         False     False     False     False     False     False     False
# 4         False     False     False     False     False     False     False
# ...         ...       ...       ...       ...       ...       ...       ...
# 77381     False     False     False     False     False     False     False
# 77382     False     False     False     False     False     False     False
# 77383     False     False     False     False     False     False     False
# 77384     False     False     False     False     False     False     False
# 77385     False     False     False     False     False     False     False
#
#        cat_6024  cat_6061
# 0         False     False
# 1         False     False
# 2         False     False
# 3         False     False
# 4         False     False
# ...         ...       ...
# 77381     False     False
# 77382     False     False
# 77383     False     False
# 77384     False     False
# 77385     False     False
#
# [77386 rows x 36 columns]

# %% [markdown]
# ### Splitting/Scaling

# %%
y = data['feed'].copy()
X = data.drop('feed', axis=1).copy()

# %%
scaler = StandardScaler()

X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=34)

# %% [markdown]
# ### Training/Results

# %%
base_model = LogisticRegression()
base_model.fit(X_train, y_train)

base_acc = base_model.score(X_test, y_test)

print('Accuracy: {:.4f}'.format(base_acc))
# Out:
# Accuracy: 0.9758

# %%
cv_model = LogisticRegressionCV()
cv_model.fit(X_train, y_train)

cv_acc = cv_model.score(X_test, y_test)

print("Accuracy: {:.4f}".format(cv_acc))
# Out:
# Accuracy: 0.9992
